# %%
import numpy as np
import torch
import tensorflow as tf

# %%
# buat matrix X dengan ukuran 2x3 menggunakan numpy
X = np.array([[19,10,16],[25,15,61]])
X
# Out:
# array([[19, 10, 16],
#        [25, 15, 61]])

# %%
X = X.T
X
# Out:
# array([[19, 25],
#        [10, 15],
#        [16, 61]])

# %%
# buat matrix X_pt dengan ukuran 2x3 menggunakan pytorch
X_pt = torch.tensor([[19,10,16],[25,15,61]])
X_pt
# Out:
# tensor([[19, 10, 16],
#         [25, 15, 61]])

# %%
X_pt.T
# Out:
# tensor([[19, 25],
#         [10, 15],
#         [16, 61]])

# %%
# buat matrix X_pt dengan ukuran 2x3 menggunakan Tensorflow
X_tf = tf.Variable([[19,10,16],[25,15,61]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[19, 10, 16],
#        [25, 15, 61]], dtype=int32)>

# %%
tf.transpose(X_tf)
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[19, 25],
#        [10, 15],
#        [16, 61]], dtype=int32)>
