# %%
import numpy as np

# %%
# buat matrix X dengan ukuran 2x3 menggunakan numpy
X = np.array([[25,15,6],[10,19,2]])
X
# Out:
# array([[25, 15,  6],
#        [10, 19,  2]])

# %%
# hitung berapa hasil penjumlahan elemen matrix X dengan fungsi sum
X.sum()
# Out:
# np.int64(77)

# %%
import tensorflow as tf

# %%
# buat matrix X_tf dengan ukuran 2x3 menggunakan tensorflow
X_tf = tf.Variable([[20,19,1],[7,12,5]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[20, 19,  1],
#        [ 7, 12,  5]], dtype=int32)>

# %%
import torch as pt

# %%
# buat matrix X_tf dengan ukuran 2x3 menggunakan pytorch
X_pt = torch.tensor([[6,7,8],[8,9,19]])
X_pt
# Out:
# tensor([[ 6,  7,  8],
#         [ 8,  9, 19]])

# %%
# hitung hasil penjumlahan seluruh elemen matrix X
X.sum()
# Out:
# np.int64(77)

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_tf
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=64>

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_pt
X_pt.sum()
# Out:
# tensor(57)

# %%
# hitung hasil penjumlahan matrix X berdasarkan row nya
X.sum(axis=0)
# Out:
# array([35, 34,  8])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan row nya
tf.reduce_sum(X_tf,axis=0)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([27, 31,  6], dtype=int32)>

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan row nya
X_pt.sum(axis=0)
# Out:
# tensor([14, 16, 27])

# %%
# hitung hasil penjumlahan matrix X berdasarkan kolom nya
X.sum(axis=1)
# Out:
# array([46, 31])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan kolom nya
tf.reduce_sum(X_tf,axis=1)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([40, 24], dtype=int32)>

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan kolom nya
X_pt.sum(axis=1)
# Out:
# tensor([21, 36])

# %%
# hitung nilai minimal dari matrix X, X_pt dan X_tf
X.min()
# Out:
# np.int64(2)

# %%
X_pt.min()
# Out:
# tensor(6)

# %%
tf.reduce_min(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
# hitung nilai maksimal dari matrix X, X_pt dan X_tf
X.max()
# Out:
# np.int64(25)

# %%
X_pt.max()
# Out:
# tensor(19)

# %%
tf.reduce_max(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=20>

# %%
# hitung nilai rata-rata dari matrix X, X_pt dan X_tf
X.mean()
# Out:
# np.float64(12.833333333333334)

# %%
X_pt.float().mean()
# Out:
# tensor(9.5000)

# %%
tf.reduce_mean(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=10>

# %%
# hitung hasil perkalian seluruh elemen matrix X

# %%
X.prod()
# Out:
# np.int64(855000)

# %%
X_pt.prod()
# Out:
# tensor(459648)

# %%
tf.reduce_prod(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=159600>
