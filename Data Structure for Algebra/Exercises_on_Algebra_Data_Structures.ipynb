# %%
# selesaikan soal berikut
# what is the trnaspose of this vector?
import numpy as np

# %%
x = ([25,
      2,
     -3,
    -23])

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = np.transpose(x)
x_t
# Out:
# array([ 25,   2,  -3, -23])
