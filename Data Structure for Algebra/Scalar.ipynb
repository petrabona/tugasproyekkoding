# %%
# variabel skalar x dan simpan suatu nilai skalar
x = 41
x
# Out:
# 41

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 14
y
# Out:
# 14

# %%
# tampilkan tipe data dari y
y = 14

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 55

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 2515.0

# %%
# jumlahkan x_float dengan y
x_float = 41.0
float_sum = x_float + y
float_sum
# Out:
# 55.0

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
import tensorflow as tf

# %%
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow
x_tf = tf.Variable(14, dtype=tf.int32)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=14>

# %%
import torch

# %%
 # lakukan tahapan pada soal 1 dengan menggunakan pytorch
  x_pt = torch.tensor(41)
x_pt
# Out:
#   File "/tmp/ipykernel_3692/458757162.py", line 2
#     x_pt = torch.tensor(41)
#     ^
# IndentationError: unexpected indent
